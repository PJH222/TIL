# %% [markdown]
# # Pandas로 그래프 그려보장~~~

# %%
import pandas as pd
import matplotlib as plt

s1 = [1,2,3,4,5,7,10]
s1 = pd.Series(s1)

s1.plot()
# Out:
# <Axes: >

# %%
import random
data = [random.randrange(1,11) for i in range(10)]
index = pd.date_range('2024-02-11',periods = 10)
da = pd.Series(data,index = index)

da.plot(grid=True)
# Out:
# <Axes: >
