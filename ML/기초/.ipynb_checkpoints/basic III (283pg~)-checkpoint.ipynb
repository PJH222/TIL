# %%
# !pip install matplotlib
# !pip list
# !pip install matplotlib --upgrade
# import matplotlib as plt

# %%
! pip show matplotlib
! pip show pandas

# %%
import matplotlib.pyplot as plt

data = [1,5,6,19,42,32]
plt.plot(data)

# %%
# import matplotlib
import sys
sys.version
# Out:
# '3.11.6 (tags/v3.11.6:8b6ee5b, Oct  2 2023, 14:57:12) [MSC v.1935 64 bit (AMD64)]'

# %% [markdown]
# # 망할 주피터...
# # matplotlib가 안먹힌다...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\장훈\AppData\Local\Programs\Python\Python311\python.exe
